# %% [markdown]
# ## Часть 1: Введение в Pandas
#
# Pandas - это библиотека Python для работы с данными. Она предоставляет мощные инструменты для анализа и манипуляции данными.
#
# ### Установка Pandas
#
# Для начала убедитесь, что у вас установлена библиотека Pandas. Если ее нет, установите ее с помощью команды:

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\alper\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: C:\Users\alper\AppData\Local\Programs\Python\Python312\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Импорт библиотеки
# Давайте начнем с импорта библиотеки Pandas:

# %%
# write your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ## Часть 2: Работа с данными
# ### Чтение данных
# Мы будем использовать датасет Titanic. Давайте прочитаем данные из CSV файла.

# %%
# Чтение данных из файла 'titanic.csv'
# Используйте метод pd.read_csv()
# write your code here

df = pd.read_csv('titanic.csv')

# %% [markdown]
# ### Предпросмотр данных
# Для первого ознакомления с данными давайте выведем первые несколько строк.

# %%
# Вывод первых 5 строк данных
# Используйте метод .head()
# write your code here
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### Информация о данных
# Чтобы получить общую информацию о данных, воспользуйтесь методом .info().

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### Работа с NaN
# Часто данные содержат пропущенные значения, которые представляются как NaN (Not a Number). Pandas предоставляет удобные методы для работы с ними.
#
# Проверка на наличие NaN. Методы fillna и dropna возвращают новые Dataframe, проверьте нет ли в них NaN

# %%
# Проверка на наличие NaN в DataFrame
# Используйте метод .isna()
# write your code here

print(df.isna().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# Заполнение NaN

# %%
# Заполнение NaN определенным значением (например, нулем)
# Используйте метод .fillna()
# write your code here
df.fillna(0, inplace=True)

# %%
print(df.isna().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# Удаление строк с NaN

# %%
# Удаление строк, содержащих NaN
# Используйте метод .dropna()
# write your code here
df.dropna(inplace=True)

# %% [markdown]
# ## Часть 3: Обработка DataFrame
# ### Выбор данных
# Pandas позволяет выбирать данные по индексам, меткам столбцов и условиям.

# %%
# Выбор столбца по метке
# Используйте синтаксис DataFrame['название_столбца']
# write your code here
df['Ticket']

# Выбор нескольких столбцов
# Используйте синтаксис DataFrame[['столбец_1', 'столбец_2']]
# write your code here
df[['Name', 'Age']]

# Выбор строк по индексу
# Используйте метод .loc[]
# write your code here
df.loc[5:15]

# Выбор строк и столбцов по условию
# Используя логические операции, выберите мужчин старше 30
# write your code here
df[(df['Sex']=='male')&(df['Age']>30)]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 4              5         0       3              Allen, Mr. William Henry
# 6              7         0       1               McCarthy, Mr. Timothy J
# 13            14         0       3           Andersson, Mr. Anders Johan
# 20            21         0       2                  Fynney, Mr. Joseph J
# 21            22         1       2                 Beesley, Mr. Lawrence
# ..           ...       ...     ...                                   ...
# 867          868         0       1  Roebling, Mr. Washington Augustus II
# 872          873         0       1              Carlsson, Mr. Frans Olof
# 873          874         0       3           Vander Cruyssen, Mr. Victor
# 881          882         0       3                    Markun, Mr. Johann
# 890          891         0       3                   Dooley, Mr. Patrick
#
#       Sex   Age  SibSp  Parch    Ticket     Fare        Cabin Embarked
# 4    male  35.0      0      0    373450   8.0500            0        S
# 6    male  54.0      0      0     17463  51.8625          E46        S
# 13   male  39.0      1      5    347082  31.2750            0        S
# 20   male  35.0      0      0    239865  26.0000            0        S
# 21   male  34.0      0      0    248698  13.0000          D56        S
# ..    ...   ...    ...    ...       ...      ...          ...      ...
# 867  male  31.0      0      0  PC 17590  50.4958          A24        S
# 872  male  33.0      0      0       695   5.0000  B51 B53 B55        S
# 873  male  47.0      0      0    345765   9.0000            0        S
# 881  male  33.0      0      0    349257   7.8958            0        S
# 890  male  32.0      0      0    370376   7.7500            0        Q
#
# [202 rows x 12 columns]

# %% [markdown]
# ### Сортировка данных
# Сортировка данных по значениям столбцов.

# %%
# Сортировка данных по столбцу 'столбец_1' по возрастанию
# Используйте метод .sort_values()
# write your code here
df.sort_values(by=['Age', 'Ticket'], ascending=True)
# Out:
#      PassengerId  Survived  Pclass  \
# 475          476         0       1
# 507          508         1       1
# 633          634         0       1
# 815          816         0       1
# 766          767         0       1
# ..           ...       ...     ...
# 116          117         0       3
# 493          494         0       1
# 96            97         0       1
# 851          852         0       3
# 630          631         1       1
#
#                                               Name   Sex   Age  SibSp  Parch  \
# 475                    Clifford, Mr. George Quincy  male   0.0      0      0
# 507  Bradley, Mr. George ("George Arthur Brayton")  male   0.0      0      0
# 633                  Parr, Mr. William Henry Marsh  male   0.0      0      0
# 815                               Fry, Mr. Richard  male   0.0      0      0
# 766                      Brewe, Dr. Arthur Jackson  male   0.0      0      0
# ..                                             ...   ...   ...    ...    ...
# 116                           Connors, Mr. Patrick  male  70.5      0      0
# 493                        Artagaveytia, Mr. Ramon  male  71.0      0      0
# 96                       Goldschmidt, Mr. George B  male  71.0      0      0
# 851                            Svensson, Mr. Johan  male  74.0      0      0
# 630           Barkworth, Mr. Algernon Henry Wilson  male  80.0      0      0
#
#        Ticket     Fare Cabin Embarked
# 475    110465  52.0000   A14        S
# 507    111427  26.5500     0        S
# 633    112052   0.0000     0        S
# 815    112058   0.0000  B102        S
# 766    112379  39.6000     0        C
# ..        ...      ...   ...      ...
# 116    370369   7.7500     0        Q
# 493  PC 17609  49.5042     0        C
# 96   PC 17754  34.6542    A5        C
# 851    347060   7.7750     0        S
# 630     27042  30.0000   A23        S
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Группировка данных
# Pandas также позволяет группировать данные и выполнять агрегирующие операции.

# %%
# Найдите долю выживших среди всех PClass
# Используйте метод .groupby()
# write your code here
live_or_die = df.groupby('Pclass')['Survived'].mean()
print(live_or_die)
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %% [markdown]
# ## Часть 4: Задания для практики
# Прочитайте данные из файла 'titanic.csv'.
# Проверьте, есть ли пропущенные значения в данных и заполните их нулями.
# Выведите первые 10 строк данных.
# Выберите только те строки, где значение в столбце 'Age' больше 30.
# Отсортируйте данные по столбцу 'Fare' в порядке убывания.
# Сгруппируйте данные по столбцу 'Pclass' и вычислите средний возраст ('Age') для каждого класса.

# %%
import pandas as pd


df = pd.read_csv('titanic.csv')



print(df.isna().sum())


df.fillna(0, inplace=True)


print(f"Toplam Kalan NaN Sayısı: {df.isna().sum().sum()}")



print(df.head(10))


older_than_30 = df[df['Age'] > 30]
print("\n--- Количество пассажиров старше 30 лет. ---")
print(f"Количество пассажиров: {len(older_than_30)}")

print(older_than_30[['Name', 'Age', 'Pclass']].head())


df_sorted_fare = df.sort_values(by='Fare', ascending=False)
print("\n--- Сортировка по тарифам в порядке убывания (самые дорогие) ---")
print(df_sorted_fare[['Name', 'Fare', 'Pclass']].head())


average_age_by_pclass = df.groupby('Pclass')['Age'].mean()
print("\n--- Средний возраст по классам Pclass ---")
print(average_age_by_pclass)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
# Toplam Kalan NaN Sayısı: 0
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   0.0      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500     0        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250     0        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500     0        S
# 5      0            330877   8.4583     0        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750     0        S
# 8      2            347742  11.1333     0        S
# 9      0            237736  30.0708     0        C
#
# --- Количество пассажиров старше 30 лет. ---
# Количество пассажиров: 305
#                                                  Name   Age  Pclass
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0       1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0       1
# 4                            Allen, Mr. William Henry  35.0       3
# 6                             McCarthy, Mr. Timothy J  54.0       1
# 11                           Bonnell, Miss. Elizabeth  58.0       1
#
# --- Сортировка по тарифам в порядке убывания (самые дорогие) ---
#                                    Name      Fare  Pclass
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292       1
# 258                    Ward, Miss. Anna  512.3292       1
# 737              Lesurer, Mr. Gustave J  512.3292       1
# 88           Fortune, Miss. Mabel Helen  263.0000       1
# 438                   Fortune, Mr. Mark  263.0000       1
#
# --- Средний возраст по классам Pclass ---
# Pclass
# 1    32.923241
# 2    28.091467
# 3    18.177026
# Name: Age, dtype: float64
